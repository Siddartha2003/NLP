# %% [markdown]
# <a href="https://colab.research.google.com/github/Siddartha2003/NLP/blob/main/Assignment_8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Example text data (you can replace this with any larger corpus) text = """ Once upon a time, there was a little girl named Red Riding Hood. She loved to visit her grandmother, who lived in the woods. One day, her mother asked her to take a basket of goodies to her grandmother. On her way through the woods, she met a big bad wolf who wanted to eat her. [CO5]
# (i) Build the Transformer Model on above dataset

# %%
import tensorflow as tf
from tensorflow.keras.layers import Embedding, MultiHeadAttention, LayerNormalization, Dense, Dropout
from tensorflow.keras import Sequential, Model
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
import numpy as np

# Sample text data
text = """Once upon a time, there was a little girl named Red Riding Hood. She loved to visit her grandmother, who lived in the woods. One day, her mother asked her to take a basket of goodies to her grandmother. On her way through the woods, she met a big bad wolf who wanted to eat her."""

# Step 1: Tokenize and Prepare Data
vocab_size = 1000  # Adjust as needed
tokenizer = Tokenizer(num_words=vocab_size, oov_token="<OOV>")
tokenizer.fit_on_texts([text])

# Convert text to sequences of tokens
sequences = tokenizer.texts_to_sequences([text])[0]

# Prepare input sequences and labels
input_sequences = []
for i in range(1, len(sequences)):
    input_sequences.append(sequences[:i+1])

# Pad sequences
max_sequence_len = max(len(x) for x in input_sequences)
input_sequences = pad_sequences(input_sequences, maxlen=max_sequence_len, padding='pre')

# Split into inputs and labels
X, y = input_sequences[:,:-1], input_sequences[:,-1]
y = tf.keras.utils.to_categorical(y, num_classes=vocab_size)

# %% [markdown]
# (ii) Train the model using 20, 60, 70 epochs

# %%
# Step 2: Build the Transformer Model
class TransformerModel(Model):
    def __init__(self, vocab_size, embed_dim, num_heads, ff_dim):
        super(TransformerModel, self).__init__()
        self.embedding = Embedding(input_dim=vocab_size, output_dim=embed_dim)
        self.attention = MultiHeadAttention(num_heads=num_heads, key_dim=embed_dim)
        self.dense_proj = Sequential([Dense(ff_dim, activation="relu"), Dense(embed_dim)])
        self.layernorm1 = LayerNormalization()
        self.layernorm2 = LayerNormalization()
        self.dropout1 = Dropout(0.1)
        self.dropout2 = Dropout(0.1)
        self.final_layer = Dense(vocab_size, activation="softmax")

    def call(self, inputs):
        x = self.embedding(inputs)
        attn_output = self.attention(x, x)
        x = self.layernorm1(x + self.dropout1(attn_output))
        ffn_output = self.dense_proj(x)
        x = self.layernorm2(x + self.dropout2(ffn_output))
        # Return the output for the last timestep only
        return self.final_layer(x[:, -1])

# Initialize the model with parameters
embed_dim = 128  # Embedding dimension
num_heads = 4    # Number of attention heads
ff_dim = 512     # Feed forward network dimension

transformer_model = TransformerModel(vocab_size, embed_dim, num_heads, ff_dim)
transformer_model.compile(optimizer="adam", loss="categorical_crossentropy", metrics=["accuracy"])

# %% [markdown]
#  (iii) After training, use the model to generate new text by feeding it an initial seed text

# %%
# Step 3: Train the model with different epochs
epochs_list = [20,60,70]
for epochs in epochs_list:
    print(f"\nTraining model with {epochs} epochs:")
    transformer_model.fit(X, y, epochs=epochs, verbose=1)
# Out:
# Training model with 20 epochs:
# Epoch 1/20
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 8s 200ms/step - accuracy: 0.0000e+00 - loss: 7.0426
# Epoch 2/20
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 204ms/step - accuracy: 0.1282 - loss: 6.0216
# Epoch 3/20
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 197ms/step - accuracy: 0.2547 - loss: 5.4182
# Epoch 4/20
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 236ms/step - accuracy: 0.3015 - loss: 4.8888
# Epoch 5/20
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 233ms/step - accuracy: 0.4506 - loss: 4.3727
# Epoch 6/20
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 229ms/step - accuracy: 0.6343 - loss: 3.8292
# Epoch 7/20
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 156ms/step - accuracy: 0.7920 - loss: 3.3778
# Epoch 8/20
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - accuracy: 0.7712 - loss: 2.9296
# Epoch 9/20
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - accuracy: 0.7955 - loss: 2.5200
# Epoch 10/20
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - accuracy: 0.8059 - loss: 2.2406
# Epoch 11/20
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 245ms/step - accuracy: 0.8163 - loss: 1.9088
# Epoch 12/20
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 263ms/step - accuracy: 0.8284 - loss: 1.5858
# Epoch 13/20
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 269ms/step - accuracy: 0.8597 - loss: 1.4057
# Epoch 14/20
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 205ms/step - accuracy: 0.8597 - loss: 1.1697
# Epoch 15/20
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 240ms/step - accuracy: 0.8614 - loss: 1.1061
# Epoch 16/20
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 239ms/step - accuracy: 0.8718 - loss: 0.9326
# Epoch 17/20
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 147ms/step - accuracy: 0.8822 - loss: 0.8384
# Epoch 18/20
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 143ms/step - accuracy: 0.8509 - loss: 0.7777
# Epoch 19/20
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 140ms/step - accuracy: 0.8648 - loss: 0.7556
# Epoch 20/20
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - accuracy: 0.8752 - loss: 0.6806
#
# Training model with 60 epochs:
# Epoch 1/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - accuracy: 0.9064 - loss: 0.5888
# Epoch 2/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 138ms/step - accuracy: 0.9186 - loss: 0.5599
# Epoch 3/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - accuracy: 0.8960 - loss: 0.5257
# Epoch 4/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step - accuracy: 0.8977 - loss: 0.5034
# Epoch 5/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - accuracy: 0.9307 - loss: 0.4775
# Epoch 6/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - accuracy: 0.9203 - loss: 0.4676
# Epoch 7/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 239ms/step - accuracy: 0.9307 - loss: 0.4064
# Epoch 8/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 224ms/step - accuracy: 0.8977 - loss: 0.4168
# Epoch 9/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - accuracy: 0.9098 - loss: 0.3770
# Epoch 10/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 144ms/step - accuracy: 0.9411 - loss: 0.3409
# Epoch 11/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - accuracy: 0.9307 - loss: 0.3195
# Epoch 12/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - accuracy: 0.9186 - loss: 0.3191
# Epoch 13/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 231ms/step - accuracy: 0.9411 - loss: 0.3007
# Epoch 14/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 322ms/step - accuracy: 0.9307 - loss: 0.2688
# Epoch 15/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 225ms/step - accuracy: 0.9532 - loss: 0.2843
# Epoch 16/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 260ms/step - accuracy: 0.9758 - loss: 0.2646
# Epoch 17/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 139ms/step - accuracy: 0.9411 - loss: 0.2475
# Epoch 18/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step - accuracy: 0.9532 - loss: 0.2392
# Epoch 19/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 150ms/step - accuracy: 0.9532 - loss: 0.2328
# Epoch 20/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 164ms/step - accuracy: 0.9203 - loss: 0.2317
# Epoch 21/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 152ms/step - accuracy: 0.9307 - loss: 0.2312
# Epoch 22/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 147ms/step - accuracy: 0.9428 - loss: 0.2050
# Epoch 23/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - accuracy: 0.9411 - loss: 0.2057
# Epoch 24/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 148ms/step - accuracy: 0.9428 - loss: 0.2116
# Epoch 25/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - accuracy: 0.9549 - loss: 0.2081
# Epoch 26/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 136ms/step - accuracy: 0.9549 - loss: 0.2125
# Epoch 27/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - accuracy: 0.9636 - loss: 0.1669
# Epoch 28/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - accuracy: 0.9411 - loss: 0.1578
# Epoch 29/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step - accuracy: 0.9636 - loss: 0.1492
# Epoch 30/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - accuracy: 0.9653 - loss: 0.1664
# Epoch 31/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 138ms/step - accuracy: 0.9879 - loss: 0.1291
# Epoch 32/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 133ms/step - accuracy: 0.9879 - loss: 0.1463
# Epoch 33/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - accuracy: 0.9653 - loss: 0.1461
# Epoch 34/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - accuracy: 0.9549 - loss: 0.1432
# Epoch 35/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 293ms/step - accuracy: 1.0000 - loss: 0.1254
# Epoch 36/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step - accuracy: 0.9879 - loss: 0.1327
# Epoch 37/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - accuracy: 0.9532 - loss: 0.1276
# Epoch 38/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - accuracy: 0.9775 - loss: 0.1280
# Epoch 39/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 191ms/step - accuracy: 0.9775 - loss: 0.1172
# Epoch 40/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 253ms/step - accuracy: 0.9879 - loss: 0.1077
# Epoch 41/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 254ms/step - accuracy: 0.9653 - loss: 0.1112
# Epoch 42/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 232ms/step - accuracy: 0.9879 - loss: 0.0994
# Epoch 43/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 251ms/step - accuracy: 0.9775 - loss: 0.1046
# Epoch 44/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 244ms/step - accuracy: 0.9653 - loss: 0.1055
# Epoch 45/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - accuracy: 0.9775 - loss: 0.0973
# Epoch 46/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 140ms/step - accuracy: 0.9758 - loss: 0.0953
# Epoch 47/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 134ms/step - accuracy: 0.9879 - loss: 0.0936
# Epoch 48/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 145ms/step - accuracy: 0.9653 - loss: 0.1289
# Epoch 49/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - accuracy: 0.9428 - loss: 0.1596
# Epoch 50/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step - accuracy: 0.9428 - loss: 0.1175
# Epoch 51/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - accuracy: 0.9549 - loss: 0.1198
# Epoch 52/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 136ms/step - accuracy: 0.9636 - loss: 0.1209
# Epoch 53/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - accuracy: 0.9549 - loss: 0.1085
# Epoch 54/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 131ms/step - accuracy: 0.9758 - loss: 0.0781
# Epoch 55/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 145ms/step - accuracy: 0.9428 - loss: 0.0878
# Epoch 56/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - accuracy: 0.9653 - loss: 0.0951
# Epoch 57/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - accuracy: 0.9532 - loss: 0.0882
# Epoch 58/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step - accuracy: 0.9653 - loss: 0.0982
# Epoch 59/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 142ms/step - accuracy: 1.0000 - loss: 0.0782
# Epoch 60/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - accuracy: 0.9428 - loss: 0.1255
#
# Training model with 70 epochs:
# Epoch 1/70
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - accuracy: 0.9549 - loss: 0.0930
# Epoch 2/70
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - accuracy: 0.9411 - loss: 0.1802
# Epoch 3/70
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 153ms/step - accuracy: 0.9879 - loss: 0.0896
# Epoch 4/70
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 127ms/step - accuracy: 0.9532 - loss: 0.1249
# Epoch 5/70
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 201ms/step - accuracy: 0.9636 - loss: 0.1189
# Epoch 6/70
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 244ms/step - accuracy: 0.9203 - loss: 0.1390
# Epoch 7/70
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 243ms/step - accuracy: 0.9307 - loss: 0.1434
# Epoch 8/70
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 228ms/step - accuracy: 0.9428 - loss: 0.1150
# Epoch 9/70
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 221ms/step - accuracy: 0.9758 - loss: 0.0862
# Epoch 10/70
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 238ms/step - accuracy: 0.9653 - loss: 0.0897
# Epoch 11/70
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 184ms/step - accuracy: 0.9653 - loss: 0.0931
# Epoch 12/70
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - accuracy: 0.9775 - loss: 0.0759
# Epoch 13/70
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - accuracy: 0.9879 - loss: 0.0678
# Epoch 14/70
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 140ms/step - accuracy: 0.9653 - loss: 0.0803
# Epoch 15/70
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 132ms/step - accuracy: 0.9775 - loss: 0.0711
# Epoch 16/70
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 146ms/step - accuracy: 1.0000 - loss: 0.0656
# Epoch 17/70
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 144ms/step - accuracy: 0.9775 - loss: 0.0699
# Epoch 18/70
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - accuracy: 0.9653 - loss: 0.0775
# Epoch 19/70
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - accuracy: 0.9775 - loss: 0.0723
# Epoch 20/70
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 136ms/step - accuracy: 0.9758 - loss: 0.0617
# Epoch 21/70
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 149ms/step - accuracy: 0.9775 - loss: 0.0560
# Epoch 22/70
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 170ms/step - accuracy: 0.9775 - loss: 0.0618
# Epoch 23/70
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 137ms/step - accuracy: 0.9775 - loss: 0.0598
# Epoch 24/70
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 136ms/step - accuracy: 0.9879 - loss: 0.0425
# Epoch 25/70
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - accuracy: 0.9775 - loss: 0.0540
# Epoch 26/70
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - accuracy: 1.0000 - loss: 0.0450
# Epoch 27/70
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - accuracy: 1.0000 - loss: 0.0479
# Epoch 28/70
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - accuracy: 0.9879 - loss: 0.0462
# Epoch 29/70
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - accuracy: 0.9653 - loss: 0.0489
# Epoch 30/70
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 133ms/step - accuracy: 0.9775 - loss: 0.0470
# Epoch 31/70
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - accuracy: 0.9775 - loss: 0.0465
# Epoch 32/70
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 220ms/step - accuracy: 1.0000 - loss: 0.0433
# Epoch 33/70
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 247ms/step - accuracy: 0.9775 - loss: 0.0446
# Epoch 34/70
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 242ms/step - accuracy: 0.9775 - loss: 0.0448
# Epoch 35/70
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 134ms/step - accuracy: 0.9879 - loss: 0.0377
# Epoch 36/70
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 146ms/step - accuracy: 1.0000 - loss: 0.0283
# Epoch 37/70
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - accuracy: 0.9879 - loss: 0.0290
# Epoch 38/70
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - accuracy: 1.0000 - loss: 0.0271
# Epoch 39/70
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - accuracy: 0.9879 - loss: 0.0357
# Epoch 40/70
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 140ms/step - accuracy: 1.0000 - loss: 0.0286
# Epoch 41/70
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step - accuracy: 0.9879 - loss: 0.0311
# Epoch 42/70
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 134ms/step - accuracy: 0.9879 - loss: 0.0297
# Epoch 43/70
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 153ms/step - accuracy: 1.0000 - loss: 0.0343
# Epoch 44/70
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - accuracy: 0.9775 - loss: 0.0498
# Epoch 45/70
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - accuracy: 0.9879 - loss: 0.0274
# Epoch 46/70
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step - accuracy: 0.9879 - loss: 0.0363
# Epoch 47/70
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - accuracy: 0.9775 - loss: 0.0374
# Epoch 48/70
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 148ms/step - accuracy: 1.0000 - loss: 0.0245
# Epoch 49/70
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 135ms/step - accuracy: 1.0000 - loss: 0.0288
# Epoch 50/70
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 135ms/step - accuracy: 1.0000 - loss: 0.0220
# Epoch 51/70
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - accuracy: 1.0000 - loss: 0.0298
# Epoch 52/70
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 134ms/step - accuracy: 0.9879 - loss: 0.0269
# Epoch 53/70
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - accuracy: 1.0000 - loss: 0.0279
# Epoch 54/70
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step - accuracy: 0.9879 - loss: 0.0298
# Epoch 55/70
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 182ms/step - accuracy: 0.9879 - loss: 0.0378
# Epoch 56/70
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 248ms/step - accuracy: 0.9775 - loss: 0.0364
# Epoch 57/70
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 254ms/step - accuracy: 0.9879 - loss: 0.0378
# Epoch 58/70
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 233ms/step - accuracy: 0.9775 - loss: 0.0417
# Epoch 59/70
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 237ms/step - accuracy: 0.9879 - loss: 0.0297
# Epoch 60/70
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 246ms/step - accuracy: 0.9653 - loss: 0.0552
# Epoch 61/70
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step - accuracy: 0.9411 - loss: 0.1787
# Epoch 62/70
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - accuracy: 0.9653 - loss: 0.0560
# Epoch 63/70
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - accuracy: 0.9186 - loss: 0.2335
# Epoch 64/70
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 132ms/step - accuracy: 0.8856 - loss: 0.1214
# Epoch 65/70
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - accuracy: 0.9064 - loss: 0.2917
# Epoch 66/70
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step - accuracy: 0.9203 - loss: 0.2845
# Epoch 67/70
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 135ms/step - accuracy: 0.9549 - loss: 0.2039
# Epoch 68/70
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 133ms/step - accuracy: 0.9307 - loss: 0.2077
# Epoch 69/70
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 139ms/step - accuracy: 0.9324 - loss: 0.1499
# Epoch 70/70
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 147ms/step - accuracy: 0.9653 - loss: 0.1120

# %% [markdown]
# (iv) Experimenting and Improving the Model by large dataset and hyper tune parameter.

# %%
# Step 4: Text Generation from a Seed Text
def generate_text(model, tokenizer, seed_text, max_length=50):
    for _ in range(max_length):
        token_list = tokenizer.texts_to_sequences([seed_text])[0]
        token_list = pad_sequences([token_list], maxlen=max_sequence_len - 1, padding='pre')
        predicted = model.predict(token_list, verbose=0)
        predicted_word_index = np.argmax(predicted, axis=-1).item()
        output_word = tokenizer.index_word.get(predicted_word_index, "")
        seed_text += " " + output_word
    return seed_text

# Generate text using a seed
seed_text = "Once upon a time"
print("\nGenerated text:", generate_text(transformer_model, tokenizer, seed_text))
# Out:
# Generated text: Once upon a time there was a time there was a little girl named red riding hood she loved to visit her mother asked her mother asked her to take a basket of goodies to her grandmother on her way through the woods she met a big bad wolf who wanted to eat her
